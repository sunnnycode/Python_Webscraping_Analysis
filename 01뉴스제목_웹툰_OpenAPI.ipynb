# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.2
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\vega2\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, intake, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page:
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\r2com\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert

# %%
import requests
import bs4
from bs4 import BeautifulSoup

# %%
print(f'request ver {requests.__version__}' )
print('beautifulsoup {}'.format(bs4.__version__))
# Out:
# request ver 2.32.2
# beautifulsoup 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스
req_param = {
    'sid': 105
}
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)
# 요청 헤더 설정 : 브라우저 정보
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
}
# requests 모듈을 사용해서 http 통신 
res = requests.get(url, headers=req_header)
print(type(res))
print(res.status_code) #200
print(res.ok) #True
if res.ok:
    # 소스보기 텍스트 가져오기
    html = res.text
    # parsing을 하기 위해서 BeautifulSoup 객체생성
    soup = BeautifulSoup(html, "html.parser")
    #print(type(soup))
    '''
        <div class='sa_text'>
            <a href='https://n.news.naver.com/mnews/article/092/0002340904' class='sa_text_title'>
               <strong class="sa_text_strong">엔씨소프트, 2분기 영업익 88억...실적 개선 박차</strong>
    '''
    #print(len(soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/article']")))
    #print(len(soup.select("div.sa_text a.sa_text_title")))
    atag_list = soup.select("div.sa_text a.sa_text_title")
    #print(type(atag_list))
    for atag in atag_list:
        # text속성: tag사이의 content, strip()공백제거
        title = atag.text.strip()
        # href 속성의 값을 추출하기
        url = atag['href']
        print(f'news 제목 = {title}')
        print(f'news 링크 = {url}')
else:
    print(f'Error 발생 {res.status_code}')
# Out:
# https://news.naver.com/section/105
# <class 'requests.models.Response'>
# 200
# True
# news 제목 = 더존비즈온, 2분기 영업익 204억…전년比 19.1%↑
# news 링크 = https://n.news.naver.com/mnews/article/003/0012709808
# news 제목 = “스마트폰 시장 3년 만에 성장세...삼성, 애플과 격차 벌릴 것”
# news 링크 = https://n.news.naver.com/mnews/article/366/0001009904
# news 제목 = “이공계 석·박사 월 80~110만 원”…‘한국형 스타이펜드’ 윤곽 나왔다
# news 링크 = https://n.news.naver.com/mnews/article/056/0011775233
# news 제목 = "파리올림픽 요트경기, 폰으로 찍었다?"... 갤S24, 모바일 생중계 지원
# news 링크 = https://n.news.naver.com/mnews/article/008/0005072793
# news 제목 = 빅테크 칼바람 속 애플만 살아남았다..서학개미 선택은?
# news 링크 = https://n.news.naver.com/mnews/article/014/0005223031
# news 제목 = 엔씨소프트, 2분기 영업익 88억 원…'리니지M' 반등에 적자 면해
# news 링크 = https://n.news.naver.com/mnews/article/374/0000396125
# news 제목 = KIST 유럽연, 28년 노하우 살려 韓 연구자 위한 거점지원센터로 탈바꿈
# news 링크 = https://n.news.naver.com/mnews/article/009/0005345610
# news 제목 = 경희대의료원, 카카오헬스케어와 ‘연구 협력 네트워크’ 협약
# news 링크 = https://n.news.naver.com/mnews/article/018/0005805272
# news 제목 = 모바일AI 체감은 역시 '통화녹음'…제조·통신사 앞다퉈 '참전'
# news 링크 = https://n.news.naver.com/mnews/article/018/0005805561
# news 제목 = 이집트 파라오의 ‘비밀’ 적혔을까…나일강 바닥서 비문 적힌 바위 찾았다[핵잼 사이언스]
# news 링크 = https://n.news.naver.com/mnews/article/081/0003470083
# news 제목 = "거기 누구 없소"…중견·중소 SI 업계, 구인난 더 심해졌다
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340945
# news 제목 = 코스피 8.77%↓, 역대급 폭락… 비트코인 시세도 패닉
# news 링크 = https://n.news.naver.com/mnews/article/138/0002179220
# news 제목 = 적자 면한 엔씨소프트, 투자·다작으로 돌파구 모색
# news 링크 = https://n.news.naver.com/mnews/article/030/0003229243
# news 제목 = 2·4분기 전년比 영업익 급감 '엔씨'…돌파구는 성장동력 발굴·비용절감
# news 링크 = https://n.news.naver.com/mnews/article/014/0005223450
# news 제목 = 방통위 김태규 "일하고 싶다…탄핵 남발 말고 상임위원 추천해달라"
# news 링크 = https://n.news.naver.com/mnews/article/014/0005223447
# news 제목 = 김태규 "방통위원장 탄핵은 희대의 촌극…국회, 상임위원 3명 추천해달라"
# news 링크 = https://n.news.naver.com/mnews/article/003/0012710700
# news 제목 = '1인체제' 방통위 직대 "국회, 상임위원 추천 진행해달라"(종합)
# news 링크 = https://n.news.naver.com/mnews/article/421/0007711164
# news 제목 = 中서 입지 좁아진 애플…삼성은 점유율 확대 재도전 [DD전자]
# news 링크 = https://n.news.naver.com/mnews/article/138/0002179219
# news 제목 = 최태원 SK "HBM 안주 말고 차세대 수익모델 고민하자"
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340942
# news 제목 = ‘리니지M 반등’ 엔씨, 2분기 영업익 88억원… “외부 투자로 동력 확보” (종합)
# news 링크 = https://n.news.naver.com/mnews/article/138/0002179216
# news 제목 = 낸드 적층 기술 경쟁...내년 400단, 2027년 1000단 쌓는다
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340940
# news 제목 = 김태규 “방통위 위원 3명 추천해달라...헌재도 신속한 심판 부탁”
# news 링크 = https://n.news.naver.com/mnews/article/119/0002858855
# news 제목 = 삼성전자, '루비콘 프로젝트' 띄운다…MS·구글·팔란티어 3파전
# news 링크 = https://n.news.naver.com/mnews/article/030/0003229219
# news 제목 = [뉴스줌인]생성형 AI 發, 국내 대기업 클라우드 시장 재편되나
# news 링크 = https://n.news.naver.com/mnews/article/030/0003229218
# news 제목 = 최재원 SK 수석부회장 장남, E&S 북미법인 입사
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340936
# news 제목 = 여름 휴가철 해외여행 통신비 아끼려면… “현지 유심, 3000원이면 1GB 데이터 하루종일”
# news 링크 = https://n.news.naver.com/mnews/article/366/0001009943
# news 제목 = 이공계 대학원생에 최대 110만원 지급
# news 링크 = https://n.news.naver.com/mnews/article/014/0005223425
# news 제목 = [1분건강] 폭염 기승에 ‘온열질환 주의보’
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340934
# news 제목 = "적자는 면했다"...엔씨, 2분기 영업이익 88억원
# news 링크 = https://n.news.naver.com/mnews/article/008/0005073094
# news 제목 = 5년만의 40도 돌파…'사상 최악' 2018년 기록 넘어설까?
# news 링크 = https://n.news.naver.com/mnews/article/584/0000028180
# news 제목 = 롯데리아, 8일부터 버거 20종 포함 68 품목 가격 인상
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340933
# news 제목 = 엔씨, 적자 간신히 면했다…2Q 영업익 88억(상보)
# news 링크 = https://n.news.naver.com/mnews/article/277/0005455213
# news 제목 = 코스피·코스닥 줄이어 서킷브레이커 발동
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340932
# news 제목 = 엔씨소프트, 적자 면했다… 2분기 영업이익 88억원
# news 링크 = https://n.news.naver.com/mnews/article/138/0002179213
# news 제목 = 韓, 반도체 대중 수출 늘자… 中 “美 수출 제재 한계 드러나”
# news 링크 = https://n.news.naver.com/mnews/article/366/0001009937
# news 제목 = ‘아재 입맛’인 줄 알았는데…믹스커피 MZ 업고 뜨나
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340930
# news 제목 = 네이버 '쇼핑 검색광고' 타고 온 '파워적립' 8년 만에 폐지
# news 링크 = https://n.news.naver.com/mnews/article/018/0005805500
# news 제목 = 한국금거래소디지털에셋 "티메프 미정산 이슈, 회사 유동성엔 영향 없어"
# news 링크 = https://n.news.naver.com/mnews/article/003/0012710560
# news 제목 = 한국 양궁 금메달 5개 '싹쓸이'...비결은?
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340929
# news 제목 = [단독] 찜통더위 부른 북태평양 고기압…한중일 손잡고 예측 정확성 높인다
# news 링크 = https://n.news.naver.com/mnews/article/366/0001009933
# news 제목 = 곤두박질치는 비트코인…'트럼프 약발' 보단 'R의 공포'
# news 링크 = https://n.news.naver.com/mnews/article/018/0005805497
# news 제목 = 서브컬처 도전한다...엔씨, 빅게임스튜디오 지분 투자
# news 링크 = https://n.news.naver.com/mnews/article/029/0002892829
# news 제목 = 이통3사 2분기 합산 영업익 예상 1.3조…전환지원금 타격 적었다
# news 링크 = https://n.news.naver.com/mnews/article/003/0012710549
# news 제목 = 배터리 화재 키우는 '열폭주' 억제 방법 찾았다
# news 링크 = https://n.news.naver.com/mnews/article/584/0000028179

# %%
section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

def print_news(sid, section):    
    # 요청 Parameter
    req_param = {
        'sid': sid
    }
    url = 'https://news.naver.com/section/{sid}'.format(**req_param)
    
    print(f'======> {url} {section} 뉴스 <======')
    
    # 요청 헤더 설정 : 브라우저 정보
    req_header = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
    }
    # requests 모듈을 사용해서 http 통신 
    res = requests.get(url, headers=req_header)
    if res.ok:
        # 소스보기 텍스트 가져오기
        html = res.text
        # parsing을 하기 위해서 BeautifulSoup 객체생성
        soup = BeautifulSoup(html, "html.parser")
        atag_list = soup.select("div.sa_text a.sa_text_title")
        for atag in atag_list:
            # text속성: tag사이의 content, strip()공백제거
            title = atag.text.strip()
            # href 속성의 값을 추출하기
            url = atag['href']
            print(f'news 제목 = {title}')
            print(f'news 링크 = {url}')
    else:
        print(f'Error 발생 {res.status_code}')

# %%
section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}
print_news(105,section_dict[105])
# Out:
# ======> https://news.naver.com/section/105 IT/과학 뉴스 <======
# news 제목 = 서울대 연구진, 전기차 배터리 열폭주 원인 찾았다…음극 코팅 통한 억지책도 제시
# news 링크 = https://n.news.naver.com/mnews/article/023/0003850644
# news 제목 = 엔씨 '빅게임스튜디오'에 370억 투자...지분·판권 확보
# news 링크 = https://n.news.naver.com/mnews/article/008/0005073077
# news 제목 = 방통위 김태규 "일하고 싶다…탄핵 남발 말고 상임위원 추천해달라"
# news 링크 = https://n.news.naver.com/mnews/article/014/0005223447
# news 제목 = 대학원생, 연구에만 매진하게…내년부터 '연구생활장려금' 지원
# news 링크 = https://n.news.naver.com/mnews/article/011/0004376120
# news 제목 = 더존비즈온, 2분기 매출 994억 원·영업이익 204억 원
# news 링크 = https://n.news.naver.com/mnews/article/138/0002179177
# news 제목 = 아이폰 16 시리즈, 9월 10일 공개 유력
# news 링크 = https://n.news.naver.com/mnews/article/421/0007710645
# news 제목 = 中서 입지 좁아진 애플…삼성은 점유율 확대 재도전 [DD전자]
# news 링크 = https://n.news.naver.com/mnews/article/138/0002179219
# news 제목 = 흑자 낸 엔씨…"인건비 줄이고 투자는 늘린다"
# news 링크 = https://n.news.naver.com/mnews/article/648/0000027927
# news 제목 = 허리띠 졸라맨 엔씨소프트, IP 확보 '총력'
# news 링크 = https://n.news.naver.com/mnews/article/293/0000057081
# news 제목 = 펄어비스 이어 엔씨까지 대규모 투자…빅게임스튜디오가 어디길래?
# news 링크 = https://n.news.naver.com/mnews/article/031/0000859460
# news 제목 = “3배 올라도 없어서 못산다” 코로나 재유행 ‘난리’…진단키트 가격 폭등
# news 링크 = https://n.news.naver.com/mnews/article/016/0002345654
# news 제목 = [컨콜] 엔씨소프트 “대작 3종 성과 기대… MMORPG 집중도 지속” (종합)
# news 링크 = https://n.news.naver.com/mnews/article/138/0002179226
# news 제목 = 적자 면한 엔씨소프트, 2분기 영업익 '88억원'… 반등 복안은
# news 링크 = https://n.news.naver.com/mnews/article/417/0001018940
# news 제목 = [사용기] 광화문 광장에 물고기가?…`갤럭시Z폴드6` AI 기능 써보니 "재밌네"
# news 링크 = https://n.news.naver.com/mnews/article/029/0002892870
# news 제목 = 김태규 방통위원장 직무대행 “이진숙 탄핵은 희대의 촌극, 국민이 피해”
# news 링크 = https://n.news.naver.com/mnews/article/030/0003229259
# news 제목 = "알리·테무 무섭네"...7월 결제추정금 전년 동기 대비 64%↑
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340953
# news 제목 = 中 창신메모리, HBM 자립 속도전…'5만장 이상 양산능력 구축'
# news 링크 = https://n.news.naver.com/mnews/article/030/0003229255
# news 제목 = `AI 작성 여부 감지기술` 공개 망설이는 오픈AI, 왜?
# news 링크 = https://n.news.naver.com/mnews/article/029/0002892864
# news 제목 = [이슈진단+] '의대 쏠림' 반도체 설계 인재·교수가 없다...통합 컨트롤 타워 필요
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340952
# news 제목 = 한국인은 잘 걸리지 않는다?…피부암 환자, 20년 새 7배 폭증
# news 링크 = https://n.news.naver.com/mnews/article/421/0007711281
# news 제목 = 워렌 버핏, 애플 지분 절반 가까이 매각...이유는
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340949
# news 제목 = [종합] 엔씨, 적자 전망 뒤집고 2분기 흑자 지속…하반기 신작 러시
# news 링크 = https://n.news.naver.com/mnews/article/031/0000859428
# news 제목 = 구글 픽셀9 프로 폴드, 실제 제품 사진 포착
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340948
# news 제목 = '방통위 정쟁 연장전'…직무 대행 "이틀 만에 탄핵 희대의 촌극"
# news 링크 = https://n.news.naver.com/mnews/article/421/0007711256
# news 제목 = 5G·LTE 알뜰폰 요금 내려갈까
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340947
# news 제목 = 김태규 "이진숙 탄핵은 촌극…상임위원 3명 추천해달라"
# news 링크 = https://n.news.naver.com/mnews/article/011/0004376178
# news 제목 = 모바일AI 체감은 역시 '통화녹음'…제조·통신사 앞다퉈 '참전'
# news 링크 = https://n.news.naver.com/mnews/article/018/0005805561
# news 제목 = "거기 누구 없소"…중견·중소 SI 업계, 구인난 더 심해졌다
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340945
# news 제목 = 이집트 파라오의 ‘비밀’ 적혔을까…나일강 바닥서 비문 적힌 바위 찾았다[핵잼 사이언스]
# news 링크 = https://n.news.naver.com/mnews/article/081/0003470083
# news 제목 = 코스피 8.77%↓, 역대급 폭락… 비트코인 시세도 패닉
# news 링크 = https://n.news.naver.com/mnews/article/138/0002179220
# news 제목 = 적자 면한 엔씨소프트, 투자·다작으로 돌파구 모색
# news 링크 = https://n.news.naver.com/mnews/article/030/0003229243
# news 제목 = 2·4분기 전년比 영업익 급감 '엔씨'…돌파구는 성장동력 발굴·비용절감
# news 링크 = https://n.news.naver.com/mnews/article/014/0005223450
# news 제목 = 방통위 김태규 "일하고 싶다…탄핵 남발 말고 상임위원 추천해달라"
# news 링크 = https://n.news.naver.com/mnews/article/014/0005223447
# news 제목 = 김태규 "방통위원장 탄핵은 희대의 촌극…국회, 상임위원 3명 추천해달라"
# news 링크 = https://n.news.naver.com/mnews/article/003/0012710700
# news 제목 = '1인체제' 방통위 직대 "국회, 상임위원 추천 진행해달라"(종합)
# news 링크 = https://n.news.naver.com/mnews/article/421/0007711164
# news 제목 = [ET단상]AI시대, 전 세계가 오픈랜에 주목하는 이유
# news 링크 = https://n.news.naver.com/mnews/article/030/0003229231
# news 제목 = 中서 입지 좁아진 애플…삼성은 점유율 확대 재도전 [DD전자]
# news 링크 = https://n.news.naver.com/mnews/article/138/0002179219
# news 제목 = 최태원 SK "HBM 안주 말고 차세대 수익모델 고민하자"
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340942
# news 제목 = AI 밸류체인 직접 챙기는 최태원…"HBM 안주 말고 수익 모델 고민하라" [인더인싸]
# news 링크 = https://n.news.naver.com/mnews/article/138/0002179218
# news 제목 = 최태원 "차세대 제품 치열하게 고민해야…6세대HBM 조기 상용화"
# news 링크 = https://n.news.naver.com/mnews/article/001/0014855535
# news 제목 = ‘리니지M 반등’ 엔씨, 2분기 영업익 88억원… “외부 투자로 동력 확보” (종합)
# news 링크 = https://n.news.naver.com/mnews/article/138/0002179216
# news 제목 = 낸드 적층 기술 경쟁...내년 400단, 2027년 1000단 쌓는다
# news 링크 = https://n.news.naver.com/mnews/article/092/0002340940
# news 제목 = [인터뷰] 이기대 스타트업얼라이언스 센터장 "이젠 '홀로서기' 할 때"
# news 링크 = https://n.news.naver.com/mnews/article/031/0000859403

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    'referer':'https://comic.naver.com/webtoon/detail?titleId=798173&no=5&amp;weekday=thu'
}
img_urls = [
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg'
]


for img_url in img_urls:
    #print(img_url)
    res = requests.get(img_url, headers=req_header)
    #print(res.status_code)
    if res.ok:
        # binary 데이터 추출
        img_data = res.content
        # url에서 file name을 가져오기
        file_name = os.path.basename(img_url)
        with open(file_name,'wb') as file:
            print(f'writing to {file_name} ({len(img_data):,} bytes)')
            file.write(img_data)
    else:
        print(f'Error 발생 {res.status_code}')
# Out:
# writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg (299,319 bytes)
# writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg (163,333 bytes)
# writing to 20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg (182,530 bytes)

# %% [markdown]
# * 현재 요청된 페이지(특정 회차)의 image 모두 다운로드 해보기

# %%
import requests
import os

webtoon_url = 'https://comic.naver.com/webtoon/detail?titleId=817945&no=37&week=mon'
req_header = {
    'referer': webtoon_url
}
# jpg image 파일명을 먼저 알아내기
res = requests.get(webtoon_url)
if res.ok: #200
    # xx.jpg 파일명 목록 가져오기
    soup = BeautifulSoup(res.text, 'html.parser')
    print(len(soup.select("img[src$='.jpg']"))) #108
    print(len(soup.select("img[src*='IMAG01']"))) #18
    img_tag_list = soup.select("img[src*='IMAG01']")

    #image 파일명을 저장할 리스트 선언
    img_url_list = []
    for img_tag in img_tag_list:
        #print(img_tag['src'])
        #image 태그의 src속성의 값을 추출해서 list에 추가하기
        img_url_list.append(img_tag['src'])

    image_dir_name = 'img'
    #img 디렉토리가 없으면 img 디렉토리 생성하기
    if not os.path.isdir(image_dir_name):
        os.mkdir(image_dir_name)
    
    for idx,img_url in enumerate(img_url_list,1):
        res = requests.get(img_url, headers=req_header)
        print(idx, res.status_code)
        if res.ok:
            # binary 데이터 추출
            img_data = res.content
            # url에서 file name을 가져오기
            file_name = os.path.basename(img_url)
            #img/xxxx.jpg
            dir_name = os.path.join(image_dir_name,file_name)
            with open(dir_name,'wb') as file:
                print(f'writing to {dir_name} ({len(img_data):,} bytes)')
                file.write(img_data)
        else:
            print(f'Error 발생 {res.status_code}')
else:
    print(res.status_code)
# Out:
# 102
# 18
# 1 200
# writing to img\20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_1.jpg (128,897 bytes)
# 2 200
# writing to img\20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_2.jpg (143,194 bytes)
# 3 200
# writing to img\20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_3.jpg (101,900 bytes)
# 4 200
# writing to img\20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_4.jpg (112,007 bytes)
# 5 200
# writing to img\20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_5.jpg (190,876 bytes)
# 6 200
# writing to img\20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_6.jpg (134,590 bytes)
# 7 200
# writing to img\20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_7.jpg (132,910 bytes)
# 8 200
# writing to img\20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_8.jpg (174,434 bytes)
# 9 200
# writing to img\20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_9.jpg (88,576 bytes)
# 10 200
# writing to img\20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_10.jpg (177,240 bytes)
# 11 200
# writing to img\20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_11.jpg (95,130 bytes)
# 12 200
# writing to img\20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_12.jpg (109,718 bytes)
# 13 200
# writing to img\20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_13.jpg (144,476 bytes)
# 14 200
# writing to img\20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_14.jpg (127,739 bytes)
# 15 200
# writing to img\20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_15.jpg (143,133 bytes)
# 16 200
# writing to img\20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_16.jpg (159,328 bytes)
# 17 200
# writing to img\20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_17.jpg (139,300 bytes)
# 18 200
# writing to img\20240226100634_548bfa8f14799d53d45b5f12df1b289e_IMAG01_18.jpg (54,967 bytes)

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %% [markdown]
# ### 4. 단축 URL 생성하는 Open API 사용하기
# * urllib 사용

# %%
import os
import sys
import urllib.request

client_id = "V" # 개발자센터에서 발급받은 Client ID 값
client_secret = "y_" # 개발자센터에서 발급받은 Client Secret 값
encText = urllib.parse.quote("https://drive.google.com/drive/u/0/folders/1V_DK7Px5w_niEKLlWhDr_GPgIYHG3Du-")
data = "url=" + encText
url = "https://openapi.naver.com/v1/util/shorturl"

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request, data=data.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
import requests

client_id = "V" # 개발자센터에서 발급받은 Client ID 값
client_secret = "y_" # 개발자센터에서 발급받은 Client Secret 값

origin_url = "https://drive.google.com/drive/u/0/folders/1V_DK7Px5w_niEKLlWhDr_GPgIYHG3Du-"

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import requests
import pprint

headers = {
    'X-Naver-Client-Id': 'V',
    'X-Naver-Client-Secret': 'y_',
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'

res = requests.get(url, params=payload, headers=headers)
items_data = res.json()['items']
#print(items_data)

items_list = list()
item_list = []
for item in items_data:
#     print(item)
    item_list.append(item['title'])
    item_list.append(item['bloggername'])
    item_list.append(item['description'])
    item_list.append(item['bloggerlink'])
    item_list.append(item['link'])

    items_list.append(item_list)
    item_list = []

print(items_list)

with open('data/nhnblog.txt','w',encoding="utf-8")as file:
    for items in items_list:
        for item in items:
            item = item + '\n'
            file.write(item)
        file.write('-'*150+'\n')
